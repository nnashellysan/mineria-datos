# %% [markdown]
# ----------------------------PRACTICA DOS-----------------------------

# %% [markdown]
# Integrantes del equipo:

# %% [markdown]
# Mayo Ruíz Ademir Sisifo

# %% [markdown]
# Ortiz Morales María José

# %% [markdown]
# Sánchez Olvera Nashelly Natasha

# %% [markdown]
# Yañez Romero Trianna Montserrat

# %%
#Importando librerias
import nltk
nltk.download('stopwords')

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.tokenize import RegexpTokenizer
import numpy as np    
from numpy import dot
from numpy.linalg import norm
import scipy as sc
from scipy.spatial import distance
import pandas as pd
import numpy as np
import missingno as msno
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stopwords.fileids()
set(stopwords.words('spanish'))
tokenizer = RegexpTokenizer(r'\w+')

# %%
path = 'tweets.csv'   #Obtenemos archivo csv con mensajes
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
#df.head()
#df['tweet'].count()

# %%
texts=[]    ### creamos arreglo de tokens 
for i in range(0,df['tweet'].count()):
    texts.append(df['tweet'][i])
#texts

text_token=[]

text_stops= [ [0 for columna in range(0,0)] for fila in range (0,df['tweet'].count())]
for i in range(0,df['tweet'].count()):
    text_token.append(tokenizer.tokenize(texts[i].lower()))

for i in range(0,df['tweet'].count()):
      for word in text_token[i]:
        if word not in stopwords.words('spanish'): text_stops[i].append(word)
#text_token
#print(text_stops)#text_token

# %%
##    Creación de la BoW
dicc_texts2={}
for i in range(0,df['tweet'].count()):
  var='tweet'+ str(i+1)
  dicc_texts2.setdefault(var,text_stops[i])

#dicc_texts2

# %%
dicc_termns2 = {}

for text in dicc_texts2:
    for word in dicc_texts2[text]:
#        print("EVALUAR:", word, "EN", text)
        if(word in dicc_termns2):#incrementar palabras al diccionario
            dicc_termns2[word] = dicc_termns2[word] + 1
#            print(word, "IN", "dicc_termns")
        elif(word not in dicc_termns2):#agregar palabras al diccionario        
            dicc_termns2[word] = 1
#            print(word, "NOT IN", "dicc_termns")            
print(len(dicc_termns2))
#dicc_termns2
# Out:
# 313

# %%
##   Matriz Término Documento (binaria)
matrixA = np.zeros((len(dicc_texts2), len(dicc_termns2)))
#matrixA

# %%
i = 0
j = 0

for word_termns2 in dicc_termns2: #dicc_termns todos los términos
    for word_texts2 in dicc_texts2: #dicc_texts todos los textos
#        print("EVALUAR:", word_termns, "EN: ", word_texts)
        if(word_termns2 in dicc_texts2[word_texts2]): #si está
            #print(word_termns2, "IN", word_texts2)
            
            matrixA[j, i] = 1
            
        elif(word_termns2 not in dicc_texts2[word_texts2]): # si no está
            #print(word_termns2, "NOT IN", word_texts2)
            
            matrixA[j, i] = 0
            
            
        #print("se agregó: ", matrixA[j,i], "en: ", j, i)
            
        j = j + 1
        
    j = 0
    i = i + 1

# %%
# calculamos la relación de cosenos (similaridad) de los textos y guardamos en un arreglo 
resultA =[]  # vector de resultados

for i in range(0,df['tweet'].count()-1):
    for j in range(i+1, df['tweet'].count()):
        resultA.append(dot(matrixA[i],matrixA[j])/(norm(matrixA[i])*norm(matrixA[j])))

#print(resultA)

# %%
#   Matriz Término Documento (frecuencia)
matrixB = np.zeros((len(dicc_texts2), len(dicc_termns2))) # Pre-allocate matrix
#matrix

# %%
i = 0
j = 0

for word_termns2 in dicc_termns2: #dicc_termns todos los términos
#    print()
    for word_texts2 in dicc_texts2: #dicc_texts todos los textos
#        print("EVALUAR:", word_termns, "EN: ", word_texts)
        if(word_termns2 in dicc_texts2[word_texts2]): #si está
            #print(word_termns2, "IN", word_texts2)
            
            matrixB[j, i] = dicc_termns2[word_termns2]
            
        elif(word_termns2 not in dicc_texts2[word_texts2]): # si no está
            #print(word_termns2, "NOT IN", word_texts2)
            
            matrixB[j, i] = 0
            
            
        #print("se agregó: ", matrixB[j,i], "en: ", j, i)
            
        j = j + 1
        
    j = 0
    i = i + 1
#matrixB

# %%
# calculamos la relación de cosenos (similaridad) de los textos y guardamos en un arreglo 
result2=[]  # vector de resultados
tweets2=[]  # vector de enfrentamientos
for i in range(0,df['tweet'].count()-1):
    for j in range(i+1, df['tweet'].count()):
        tweets2.append('tweet '+str(i+1)+' vs '+str(j+1))
        result2.append(dot(matrixB[i],matrixB[j])/(norm(matrixB[i])*norm(matrixB[j])))

# %%
matriz =[]  #creamos una matriz auxiliar que guardará los indices de los mensajes comparados 
k=0
for i in range(0,df['tweet'].count()-1):
    for j in range(i+1, df['tweet'].count()):
        matriz.append([])
        matriz[k].append(k)
        matriz[k].append(i)
        matriz[k].append(j)
        k=k+1
#print(matriz)

# %%
#  Imprimimos los resultados
meanSim=sum(resultA)/len(resultA)

print('Los tweets con mayor relación son:','\n')
for i in range(0,len(resultA)):
  if(resultA[i]>meanSim):
    print(tweets2[i],' , similaridad ',resultA[i],'\n')
    print('\t','\t',matriz[i][1]+1,' :',df['tweet'][matriz[i][1]],'\n')
    print('\t','\t',matriz[i][2]+1,' :',df['tweet'][matriz[i][2]],'\n')
# Out:
# Los tweets con mayor relación son:
#
# tweet 1 vs 2  , similaridad  0.04999999999999999
#
# 	 	 1  : Se celebran? Chale que conformista para américa es un buen resultado pero para pumas no mucho menos cuando sabes que el equipo jugó bien pero siempre tu portero la va a cagar en cada partido y echara a perder todo como siempre
#
# 	 	 2  : Este empate no se puede celebrar ! Da coraje ! Regalas un gol y t empatan en el último minuto ! Q se va a celebrar ! El america mas parchado q nunca ! Y ni así le ganamos ! Ya son mamadas ! Q se va a celebrar ?
#
# tweet 1 vs 13  , similaridad  0.04225771273642582
#
# 	 	 1  : Se celebran? Chale que conformista para américa es un buen resultado pero para pumas no mucho menos cuando sabes que el equipo jugó bien pero siempre tu portero la va a cagar en cada partido y echara a perder todo como siempre
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# tweet 1 vs 17  , similaridad  0.09325048082403138
#
# 	 	 1  : Se celebran? Chale que conformista para américa es un buen resultado pero para pumas no mucho menos cuando sabes que el equipo jugó bien pero siempre tu portero la va a cagar en cada partido y echara a perder todo como siempre
#
# 	 	 17  : ser un sexual worker no te hace menos mujer/hombre ni apoyarlo es un sinónimo de faltarle el respeto... es un trabajo como cualquier otro por el que le PAGAN. La decisión de trabajarlo es de cada cuál. No lo confundan con explotación sexual, violaciones ni tráfico humano
#
# tweet 1 vs 19  , similaridad  0.08304547985373997
#
# 	 	 1  : Se celebran? Chale que conformista para américa es un buen resultado pero para pumas no mucho menos cuando sabes que el equipo jugó bien pero siempre tu portero la va a cagar en cada partido y echara a perder todo como siempre
#
# 	 	 19  : Rogelio Funes Mori no jugará vs Chivas el sábado por acumulación de 5 tarjetas amarillas. Y por GDL, Alexis Vega recibió igual un partido de suspensión por la tarjeta roja. ¿Quién es más determinante en su equipo? Pienso que Alexis. Como quiera Rayados ahí tiene al Toro Janssen
#
# tweet 2 vs 3  , similaridad  0.05590169943749474
#
# 	 	 2  : Este empate no se puede celebrar ! Da coraje ! Regalas un gol y t empatan en el último minuto ! Q se va a celebrar ! El america mas parchado q nunca ! Y ni así le ganamos ! Ya son mamadas ! Q se va a celebrar ?
#
# 	 	 3  : Más que celebrar, francamente molesta y enoja que por culpa muy sospechosa de $aldivar, se pierdan 2 puntos que tal vez al final del torneo, sean la diferencia para calificar.
#
# tweet 2 vs 13  , similaridad  0.04225771273642582
#
# 	 	 2  : Este empate no se puede celebrar ! Da coraje ! Regalas un gol y t empatan en el último minuto ! Q se va a celebrar ! El america mas parchado q nunca ! Y ni así le ganamos ! Ya son mamadas ! Q se va a celebrar ?
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# tweet 4 vs 5  , similaridad  0.08606629658238703
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# tweet 4 vs 7  , similaridad  0.0890870806374748
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# tweet 6 vs 9  , similaridad  0.05923488777590923
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# tweet 7 vs 11  , similaridad  0.05572782125753529
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# tweet 7 vs 17  , similaridad  0.05572782125753529
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 17  : ser un sexual worker no te hace menos mujer/hombre ni apoyarlo es un sinónimo de faltarle el respeto... es un trabajo como cualquier otro por el que le PAGAN. La decisión de trabajarlo es de cada cuál. No lo confundan con explotación sexual, violaciones ni tráfico humano
#
# tweet 8 vs 17  , similaridad  0.047836487323493986
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 17  : ser un sexual worker no te hace menos mujer/hombre ni apoyarlo es un sinónimo de faltarle el respeto... es un trabajo como cualquier otro por el que le PAGAN. La decisión de trabajarlo es de cada cuál. No lo confundan con explotación sexual, violaciones ni tráfico humano
#
# tweet 8 vs 20  , similaridad  0.11470786693528087
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 10 vs 11  , similaridad  0.042562826537937436
#
# 	 	 10  : Senadores del PAN denuncian espionaje, Morena dice que es montaje Este jueves legisladores del PAN denunciaron actos de espionaje mostrando micrófonos que presuntamente encontraron en sus oficinas. En respuesta, senadores de Morena dijeron que se trata de un montaje. La FGR ya abrió una carpeta de investigación sobre lo sucedido
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# tweet 11 vs 13  , similaridad  0.03940552031195503
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# tweet 11 vs 17  , similaridad  0.04347826086956522
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# 	 	 17  : ser un sexual worker no te hace menos mujer/hombre ni apoyarlo es un sinónimo de faltarle el respeto... es un trabajo como cualquier otro por el que le PAGAN. La decisión de trabajarlo es de cada cuál. No lo confundan con explotación sexual, violaciones ni tráfico humano

# %% [markdown]
# Disimilaridad (Distancia Euclidiana)

# %%
#Calculando la distancia apartir de la matrix de Frecuencias
resultados=[]
for i in range(0,matrixB.shape[0]-1):
  for j in range(i+1,matrixB.shape[0]):
    resultados.append(distance.euclidean(matrixB[i],matrixB[j]))

# %%
mean=sum(resultados)/len(resultados)
mean
# Out:
# 6.976163132418772

# %%
#  Imprimimos los resultados
print('Los tweets con menor disimilaridad son:','\n')
for i in range(0,len(resultados)):
  if(resultados[i]<mean):
    print(tweets2[i],' , disimilaridad ',resultados[i],'\n')
    print('\t','\t',matriz[i][1]+1,' :',df['tweet'][matriz[i][1]],'\n')
    print('\t','\t',matriz[i][2]+1,' :',df['tweet'][matriz[i][2]],'\n')
# Out:
# Los tweets con menor disimilaridad son:
#
# tweet 3 vs 4  , disimilaridad  6.782329983125268
#
# 	 	 3  : Más que celebrar, francamente molesta y enoja que por culpa muy sospechosa de $aldivar, se pierdan 2 puntos que tal vez al final del torneo, sean la diferencia para calificar.
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# tweet 3 vs 12  , disimilaridad  6.082762530298219
#
# 	 	 3  : Más que celebrar, francamente molesta y enoja que por culpa muy sospechosa de $aldivar, se pierdan 2 puntos que tal vez al final del torneo, sean la diferencia para calificar.
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 3 vs 15  , disimilaridad  5.830951894845301
#
# 	 	 3  : Más que celebrar, francamente molesta y enoja que por culpa muy sospechosa de $aldivar, se pierdan 2 puntos que tal vez al final del torneo, sean la diferencia para calificar.
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 3 vs 18  , disimilaridad  5.830951894845301
#
# 	 	 3  : Más que celebrar, francamente molesta y enoja que por culpa muy sospechosa de $aldivar, se pierdan 2 puntos que tal vez al final del torneo, sean la diferencia para calificar.
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 3 vs 20  , disimilaridad  6.164414002968976
#
# 	 	 3  : Más que celebrar, francamente molesta y enoja que por culpa muy sospechosa de $aldivar, se pierdan 2 puntos que tal vez al final del torneo, sean la diferencia para calificar.
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 4 vs 5  , disimilaridad  5.0
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# tweet 4 vs 6  , disimilaridad  6.0
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# tweet 4 vs 7  , disimilaridad  5.744562646538029
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# tweet 4 vs 8  , disimilaridad  6.324555320336759
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# tweet 4 vs 9  , disimilaridad  6.082762530298219
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# tweet 4 vs 12  , disimilaridad  4.58257569495584
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 4 vs 14  , disimilaridad  5.916079783099616
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 4 vs 15  , disimilaridad  4.242640687119285
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 4 vs 16  , disimilaridad  6.0
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 4 vs 18  , disimilaridad  4.242640687119285
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 4 vs 20  , disimilaridad  4.69041575982343
#
# 	 	 4  : Te faltó una conclusión Malcorra le pasó la estafeta del más odiado a SALDIVAR a partir de hoy
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 5 vs 6  , disimilaridad  6.244997998398398
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# tweet 5 vs 7  , disimilaridad  6.6332495807108
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# tweet 5 vs 8  , disimilaridad  6.557438524302
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# tweet 5 vs 9  , disimilaridad  6.324555320336759
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# tweet 5 vs 12  , disimilaridad  4.898979485566356
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 5 vs 14  , disimilaridad  6.164414002968976
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 5 vs 15  , disimilaridad  4.58257569495584
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 5 vs 16  , disimilaridad  6.244997998398398
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 5 vs 18  , disimilaridad  4.58257569495584
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 5 vs 20  , disimilaridad  5.0
#
# 	 	 5  : Se pudo ganar, pero el pollo en dos goles ni se avento y ni hablar del error, no veo que lo critiques atu consentido del inutil de saldivar #FueraSaldivar
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 6 vs 7  , disimilaridad  6.855654600401044
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# tweet 6 vs 8  , disimilaridad  6.782329983125268
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# tweet 6 vs 9  , disimilaridad  5.916079783099616
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# tweet 6 vs 12  , disimilaridad  5.196152422706632
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 6 vs 14  , disimilaridad  6.4031242374328485
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 6 vs 15  , disimilaridad  4.898979485566356
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 6 vs 16  , disimilaridad  6.48074069840786
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 6 vs 18  , disimilaridad  4.898979485566356
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 6 vs 20  , disimilaridad  5.291502622129181
#
# 	 	 6  : El calentamiento global es un problema ambiental, pero allí se agita algo peor: es un problema que se soluciona con decisiones políticas. Es decir, éticas. En resumen, el planeta está perdido.
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 7 vs 9  , disimilaridad  6.928203230275509
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# tweet 7 vs 12  , disimilaridad  5.656854249492381
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 7 vs 14  , disimilaridad  6.782329983125268
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 7 vs 15  , disimilaridad  5.385164807134504
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 7 vs 16  , disimilaridad  6.855654600401044
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 7 vs 18  , disimilaridad  5.385164807134504
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 7 vs 20  , disimilaridad  5.744562646538029
#
# 	 	 7  : Hoy el rector de la  @UNAM_MX  anunció el mayor programa para conseguir la equidad de género y combatir la violencia de género de cualquier institución mexicana.
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 8 vs 9  , disimilaridad  6.855654600401044
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# tweet 8 vs 12  , disimilaridad  5.5677643628300215
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 8 vs 14  , disimilaridad  6.708203932499369
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 8 vs 15  , disimilaridad  5.291502622129181
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 8 vs 16  , disimilaridad  6.782329983125268
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 8 vs 18  , disimilaridad  5.291502622129181
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 8 vs 20  , disimilaridad  4.898979485566356
#
# 	 	 8  : #AEstaHora en la Casa de Nariño nos reunimos con representantes de los distintos gremios, para hacer un balance informativo sobre la presencia y el manejo del coronavirus en nuestro país. Es fundamental el trabajo conjunto para enfrentar este reto
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 9 vs 12  , disimilaridad  5.291502622129181
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 9 vs 14  , disimilaridad  6.48074069840786
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 9 vs 15  , disimilaridad  5.0
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 9 vs 16  , disimilaridad  6.557438524302
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 9 vs 18  , disimilaridad  5.0
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 9 vs 20  , disimilaridad  5.385164807134504
#
# 	 	 9  : LOS OSOS POLARES, TAMBIÉN, EN PELIGRO DE EXTINCIÓN La falta de alimento, el derretimiento del hielo y la actividad humana están provocando que, estos animales, se vean obligados a comerse los unos a los otros. Urgen políticas que protejan a nuestro y a todos sus habitantes!
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 10 vs 12  , disimilaridad  6.928203230275509
#
# 	 	 10  : Senadores del PAN denuncian espionaje, Morena dice que es montaje Este jueves legisladores del PAN denunciaron actos de espionaje mostrando micrófonos que presuntamente encontraron en sus oficinas. En respuesta, senadores de Morena dijeron que se trata de un montaje. La FGR ya abrió una carpeta de investigación sobre lo sucedido
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 10 vs 15  , disimilaridad  6.708203932499369
#
# 	 	 10  : Senadores del PAN denuncian espionaje, Morena dice que es montaje Este jueves legisladores del PAN denunciaron actos de espionaje mostrando micrófonos que presuntamente encontraron en sus oficinas. En respuesta, senadores de Morena dijeron que se trata de un montaje. La FGR ya abrió una carpeta de investigación sobre lo sucedido
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 10 vs 18  , disimilaridad  6.708203932499369
#
# 	 	 10  : Senadores del PAN denuncian espionaje, Morena dice que es montaje Este jueves legisladores del PAN denunciaron actos de espionaje mostrando micrófonos que presuntamente encontraron en sus oficinas. En respuesta, senadores de Morena dijeron que se trata de un montaje. La FGR ya abrió una carpeta de investigación sobre lo sucedido
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 11 vs 12  , disimilaridad  6.782329983125268
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# tweet 11 vs 15  , disimilaridad  6.557438524302
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 11 vs 18  , disimilaridad  6.557438524302
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 11 vs 20  , disimilaridad  6.855654600401044
#
# 	 	 11  : Respuesta en @laoctavasports al comunicado lleno de MENTIRAS por parte de @PumasMX sobre lamentablemente caso de acoso sexual que ocultaron sobre "Valentina' para proteger a su joya de la cantera. Una vergüenza que una directiva ASI represente a la @UNAM_MX Gracias por compartir
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 12 vs 13  , disimilaridad  6.557438524302
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# tweet 12 vs 14  , disimilaridad  5.0990195135927845
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# tweet 12 vs 15  , disimilaridad  3.0
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 12 vs 16  , disimilaridad  5.196152422706632
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 12 vs 18  , disimilaridad  3.0
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 12 vs 19  , disimilaridad  6.6332495807108
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 19  : Rogelio Funes Mori no jugará vs Chivas el sábado por acumulación de 5 tarjetas amarillas. Y por GDL, Alexis Vega recibió igual un partido de suspensión por la tarjeta roja. ¿Quién es más determinante en su equipo? Pienso que Alexis. Como quiera Rayados ahí tiene al Toro Janssen
#
# tweet 12 vs 20  , disimilaridad  3.605551275463989
#
# 	 	 12  : No me había fijado en un detalle en muchas de las fotos de Andrés comiendo
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 13 vs 15  , disimilaridad  6.324555320336759
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 13 vs 18  , disimilaridad  6.324555320336759
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 13 vs 20  , disimilaridad  6.6332495807108
#
# 	 	 13  : Desconocía la situación de Marco García hasta que @PumasMX aceptó los hechos. Sin importar la edad, es indignante que alguien haga algo así. Pumas debió tener mano dura y despedir al jugador, increíble que el castigo haya sido tan pobre. Lo lamento por los valores de la UNAM.
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 14 vs 15  , disimilaridad  4.795831523312719
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# 	 	 15  : No mires esto si tienes diabetes
#
# tweet 14 vs 16  , disimilaridad  6.4031242374328485
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 14 vs 18  , disimilaridad  4.795831523312719
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 14 vs 20  , disimilaridad  5.196152422706632
#
# 	 	 14  : "El feminicido no existe, es término político": Paty Navidad Además la actriz consideró que la palabra feminicidio se utiliza para mantener el odio y separar a la sociedad http://eluni.mx/db0kmym1d
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 15 vs 16  , disimilaridad  4.898979485566356
#
# 	 	 15  : No mires esto si tienes diabetes
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# tweet 15 vs 17  , disimilaridad  6.782329983125268
#
# 	 	 15  : No mires esto si tienes diabetes
#
# 	 	 17  : ser un sexual worker no te hace menos mujer/hombre ni apoyarlo es un sinónimo de faltarle el respeto... es un trabajo como cualquier otro por el que le PAGAN. La decisión de trabajarlo es de cada cuál. No lo confundan con explotación sexual, violaciones ni tráfico humano
#
# tweet 15 vs 18  , disimilaridad  2.449489742783178
#
# 	 	 15  : No mires esto si tienes diabetes
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 15 vs 19  , disimilaridad  6.4031242374328485
#
# 	 	 15  : No mires esto si tienes diabetes
#
# 	 	 19  : Rogelio Funes Mori no jugará vs Chivas el sábado por acumulación de 5 tarjetas amarillas. Y por GDL, Alexis Vega recibió igual un partido de suspensión por la tarjeta roja. ¿Quién es más determinante en su equipo? Pienso que Alexis. Como quiera Rayados ahí tiene al Toro Janssen
#
# tweet 15 vs 20  , disimilaridad  3.1622776601683795
#
# 	 	 15  : No mires esto si tienes diabetes
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 16 vs 18  , disimilaridad  4.898979485566356
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 16 vs 20  , disimilaridad  5.291502622129181
#
# 	 	 16  : Pues el mundo siguió girando. No hubo esas pérdidas masivas por el paro nacional que pronosticaban los genios economistas como Ciro o David Páramo. Ya mañana los conservas se olvidarán del feminismo y se convertirán en expertos en economía
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 17 vs 18  , disimilaridad  6.782329983125268
#
# 	 	 17  : ser un sexual worker no te hace menos mujer/hombre ni apoyarlo es un sinónimo de faltarle el respeto... es un trabajo como cualquier otro por el que le PAGAN. La decisión de trabajarlo es de cada cuál. No lo confundan con explotación sexual, violaciones ni tráfico humano
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# tweet 18 vs 19  , disimilaridad  6.4031242374328485
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# 	 	 19  : Rogelio Funes Mori no jugará vs Chivas el sábado por acumulación de 5 tarjetas amarillas. Y por GDL, Alexis Vega recibió igual un partido de suspensión por la tarjeta roja. ¿Quién es más determinante en su equipo? Pienso que Alexis. Como quiera Rayados ahí tiene al Toro Janssen
#
# tweet 18 vs 20  , disimilaridad  3.1622776601683795
#
# 	 	 18  : la existencia es verdaderamente pesada
#
# 	 	 20  : mi familia viéndome hacer algo productivo
#
# tweet 19 vs 20  , disimilaridad  6.708203932499369
#
# 	 	 19  : Rogelio Funes Mori no jugará vs Chivas el sábado por acumulación de 5 tarjetas amarillas. Y por GDL, Alexis Vega recibió igual un partido de suspensión por la tarjeta roja. ¿Quién es más determinante en su equipo? Pienso que Alexis. Como quiera Rayados ahí tiene al Toro Janssen
#
# 	 	 20  : mi familia viéndome hacer algo productivo
